# %%
import json
import numpy as np
from dscribe.descriptors import ACSF
from pymatgen.core import Structure
from ase import Atoms
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
S_min = -1
S_max = 1
acsf_descriptors = []
target_energies = []

def precondition_symmetry_functions(symmetry_functions, S_min, S_max):
    # Step 1: Shifting the Mean to Zero
    mean_values = np.mean(symmetry_functions, axis=0)
    shifted_symmetry_functions = symmetry_functions - mean_values

    # Step 2: Rescaling to a Predefined Interval
    min_values = np.min(shifted_symmetry_functions, axis=0)
    max_values = np.max(shifted_symmetry_functions, axis=0)
    
    # Ensure no division by zero
    max_values[max_values == min_values] += 1e-12
    
    rescaled_symmetry_functions = (shifted_symmetry_functions - min_values) / (max_values - min_values) * (S_max - S_min) + S_min
    
    return rescaled_symmetry_functions


with open('position_force_train_all.json', 'r') as f:
    p_f = json.loads(f.read())

acsf = ACSF(
    species=["B"],
    r_cut=4.0,
    g2_params=[[1, 1], [1, 2], [1, 3]],
    g4_params=[[1, 1, 1], [1, 2, 1], [1, 1, -1], [1, 2, -1]],
    periodic=True
)

# Initialize empty lists to store ACSF descriptors and target energies
acsf_descriptors = []
target_energies = []

# for i in range(len(p_f)):
for i in range(1000):
    pmg_structure = Structure.from_dict(p_f[i]['structure'])
    energy = p_f[i]['energy']
    forces = p_f[i]['forces']
    bc = p_f[i]['bc']
    pbc = [0, 0, 0] if 'free' in bc else [1,1,1]
    ase_structure = Atoms(pmg_structure.composition.formula, positions=pmg_structure.cart_coords, cell=pmg_structure.lattice.matrix, pbc=pbc)
    acsf_value = acsf.create(ase_structure)
    acsf_descriptors.append(precondition_symmetry_functions(acsf_value, S_min, S_max))
#     print(precondition_symmetry_functions(acsf_value, S_min, S_max))
    target_energies.append(energy)

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset, random_split
import torch.nn.utils.rnn as rnn_utils
from sklearn.preprocessing import StandardScaler

packed_acsf_tensor = rnn_utils.pack_sequence([torch.tensor(seq) for seq in acsf_descriptors], enforce_sorted=False)

# Use the packed sequence directly or convert it to a padded sequence if needed
# Example: Convert packed sequence to a padded sequence
padded_acsf_tensor, _ = rnn_utils.pad_packed_sequence(packed_acsf_tensor, batch_first=True, padding_value=0.0)

# Assuming target_energies is a NumPy array containing the target total energies for each structure
target_energies = torch.tensor(target_energies, dtype=torch.float32)

# Combine ACSF descriptors and target energies into a PyTorch Dataset
dataset = TensorDataset(padded_acsf_tensor, target_energies)

# Split the dataset into training and validation sets (80% - 20%)
train_size = int(0.8 * len(dataset))
val_size = len(dataset) - train_size
train_dataset, val_dataset = random_split(dataset, [train_size, val_size])

# Create DataLoader for training and validation sets
batch_size = 500
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)


# Define your neural network architecture
class AtomEnergyNN(nn.Module):
    def __init__(self, input_size, hidden_size_1, hidden_size_2, output_size):
        super(AtomEnergyNN, self).__init__()
        self.fc1 = nn.Linear(input_size, hidden_size_1, dtype=torch.double)
        self.relu1 = nn.ReLU()                                                         #self.tanh1 = nn.Tanh()
        self.fc2 = nn.Linear(hidden_size_1, hidden_size_2, dtype=torch.double)
        self.relu2= nn.ReLU()
        self.fc3 = nn.Linear(hidden_size_2, output_size, dtype=torch.double)

    def forward(self, x):
        x = self.fc1(x)
        x = self.relu1(x)
        x = self.fc2(x)
        x = self.relu2(x)
        x = self.fc3(x)
        return x

# Set parameters
input_size = 8  # Number of features in ACSF descriptor for each atom
hidden_size_1 = 16  # Number of neurons in the hidden layer 1
hidden_size_2 = 16 # Number of neurons in the hidden layer 2
output_size = 1  # Single output for each atom's energy

# Create the neural network
model = AtomEnergyNN(input_size, hidden_size_1, hidden_size_2, output_size)

# Define the loss function and optimizer
criterion = torch.nn.MSELoss()  # Mean Squared Error loss
# optimizer = optim.Adam(model.parameters(), lr=0.01)  # Adam optimizer
optimizer = optim.SGD(model.parameters(), lr=0.05)     #SGD optimizer

# %%
import torch
import torch.optim as optim

# Define your optimizer, for example:
optimizer = optim.SGD(model.parameters(), lr=0.1)

# Define your loss function, for example:
loss_function = torch.nn.MSELoss()
requires_grad = True

# Define batch size
batch_size = 100  # Adjust as needed

# Define number of epochs
num_epochs = 10  # Adjust as needed

# Training loop with epochs and batch training
for epoch in range(num_epochs):
    batch_no = 0
    # Iterate over the data in batches within each epoch
    for batch_start in range(0, len(padded_acsf_tensor), batch_size):
        # Zero the gradients
        optimizer.zero_grad()
        batch_no += 1
        batch_end = min(batch_start + batch_size, len(padded_acsf_tensor))
        batch_acsf_tensor = padded_acsf_tensor[batch_start:batch_end]

        # Compute total energy for each structure in the batch
        total_energies = []
        target_total_energies = []
        for struct_acsf_tensor, target_energy in zip(batch_acsf_tensor, target_energies[batch_start:batch_end]):
            struct_acsf_tensor = struct_acsf_tensor[struct_acsf_tensor.any(dim=1)]
            total_energy = model(struct_acsf_tensor).sum().item()
            total_energies.append(total_energy)
            target_total_energies.append(target_energy.item())

            # Print predicted and actual energies for each structure
            print(f"Epoch {epoch + 1}/{num_epochs} Batch {batch_no}")
            print('Predicted Energy and actual energy:', total_energy, target_energy.item())

        # Compute loss for the batch
        predicted_energies = torch.tensor(total_energies, dtype=torch.float32, requires_grad = True)
        target_energies_batch = torch.tensor(target_total_energies, dtype=torch.float32)
        loss = criterion(predicted_energies, target_energies_batch)
        print('Loss:', loss.item())

        # Check if gradients are being computed for fc1.weight
        for name, param in model.named_parameters():
            if name == 'fc2.weight':
                print(name, param.data)  # Ensure that fc1.weight requires gradients

#         # Zero the gradients
#         optimizer.zero_grad()
        
        # Backpropagation
        loss.backward()

        # Update the weights
        optimizer.step()
# Out:
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -7.028735051439224 -157.06329345703125
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -7.028735051439224 -157.06329345703125
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -6.878911497869062 -156.97494506835938
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -7.062438862461599 -156.88255310058594
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -7.443200856212064 -156.6575164794922
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -6.730251580028099 -156.48768615722656
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -6.4377556966548255 -156.21478271484375
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -22.55747415929531 -554.1339111328125
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -22.55747415929531 -554.1339111328125
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -22.82103504622723 -553.8827514648438
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -23.23789281889378 -553.5497436523438
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -23.16001686047438 -552.1422119140625
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -22.976691178799026 -551.7311401367188
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -23.94880447658562 -549.706787109375
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -24.24805240658063 -549.3270874023438
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -24.147956379548372 -548.971923828125
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -29.378668975774502 -537.402587890625
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -29.378668975774502 -537.402587890625
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -29.48493244541464 -537.3529663085938
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -29.556495754979636 -536.6201782226562
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -29.06902773440593 -536.35498046875
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -28.815987057584326 -536.0747680664062
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -28.148036434872797 -535.0145874023438
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -29.857585380519282 -533.1719360351562
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -8.112985471576762 -172.506103515625
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -8.112985471576762 -172.506103515625
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -8.28954271612277 -172.42202758789062
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -8.043322750254774 -172.28103637695312
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -7.035842784010577 -165.1140899658203
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -7.035842784010577 -165.1140899658203
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -27.11273776427649 -577.135498046875
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -27.11273776427649 -577.135498046875
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -27.074125730047054 -577.06982421875
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -26.893693618163454 -576.9014282226562
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -26.75818463307111 -576.0357055664062
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -26.01638027733735 -575.630126953125
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -28.096104248981252 -574.8894653320312
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -28.720856135111248 -573.8357543945312
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -28.20323155153725 -571.8331909179688
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -29.36139126509642 -568.4617919921875
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -28.475060491447955 -568.1502075195312
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -28.48130361646652 -565.9724731445312
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -29.071678323834636 -565.205322265625
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -28.87279630583756 -565.0123291015625
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -29.168999909201553 -563.8114624023438
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -27.190386859005788 -578.1500244140625
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -27.190386859005788 -578.1500244140625
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -27.62974154781305 -577.9699096679688
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -27.525356037812465 -577.7468872070312
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -27.68335764829103 -577.9420166015625
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -25.71196434887273 -586.5313110351562
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -25.71196434887273 -586.5313110351562
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -25.632311672302894 -586.4581909179688
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -26.238658863731153 -585.149658203125
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -26.14517293134874 -584.9562377929688
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -25.297903152280973 -584.3641357421875
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -17.10136388223117 -256.7581787109375
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -17.10136388223117 -256.7581787109375
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -17.1316299888413 -256.48150634765625
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -27.98360633530951 -570.3096313476562
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -27.98360633530951 -570.3096313476562
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -7.282948757581468 -140.910400390625
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -7.282948757581468 -140.910400390625
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -7.3278328121307865 -140.8838653564453
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -6.700673246958929 -166.37457275390625
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -6.705832727329568 -166.37367248535156
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -6.71038362165783 -166.3728790283203
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -6.712697969823749 -166.37338256835938
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -6.680558405061566 -166.39096069335938
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -6.654851406827303 -166.4110870361328
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -6.6551836184775315 -166.41822814941406
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -14.4767538155199 -286.2998046875
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -14.4767538155199 -286.2998046875
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -14.49878558580327 -286.2329406738281
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -14.587967029484517 -285.7249755859375
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -14.495869466221293 -285.47540283203125
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -24.795063388889726 -564.7655639648438
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -24.795063388889726 -564.7655639648438
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -24.875242569606932 -564.7068481445312
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -25.197821348214145 -564.1258544921875
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -25.504941589704085 -563.9931640625
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -27.2024889498697 -561.874267578125
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -25.826520571356156 -561.35498046875
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -25.565276353198783 -561.3336791992188
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -25.120448509646838 -561.0216064453125
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -24.788159517044804 -560.8244018554688
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -28.85676077183838 -575.1926879882812
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -28.85676077183838 -575.1926879882812
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -28.45215522073061 -575.0057983398438
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -28.420136906210747 -574.7974853515625
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -12.60137214951528 -259.2908630371094
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -27.644498655811603 -548.5465698242188
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -27.644498655811603 -548.5465698242188
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -27.837410911223387 -548.19189453125
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -28.393050777875118 -546.6704711914062
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -27.513934447482384 -545.929931640625
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -28.125079474146666 -544.7905883789062
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -28.0633174461867 -544.7706298828125
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -28.020325338454533 -544.447265625
# Epoch 1/10 Batch 1
# Predicted Energy and actual energy: -14.036309432385107 -295.9552307128906
# Loss: 204560.625
# fc2.weight tensor([[-2.3017e-02,  2.4867e-01, -9.0384e-02,  2.2981e-01, -2.0484e-01,
#          -7.7866e-03,  1.2468e-01, -1.2984e-01,  3.2675e-02, -1.8956e-01,
#           1.7521e-01, -2.0414e-01, -1.8847e-01, -1.8600e-01, -1.6917e-01,
#          -1.3337e-01],
#         [-1.7104e-01, -2.1066e-01, -1.5134e-01, -9.9021e-02, -1.8519e-01,
#          -1.1152e-02, -6.8181e-02, -8.8197e-02, -1.1343e-01, -2.4065e-01,
#           1.3579e-01, -7.6533e-02,  2.0688e-01,  4.0513e-02, -9.6893e-02,
#          -2.3026e-02],
#         [ 7.6858e-02,  2.0925e-01, -1.9633e-01,  1.4729e-01,  3.5941e-02,
#           1.9597e-01,  3.7686e-02, -8.8825e-02,  3.4985e-02, -2.0993e-01,
#          -1.1715e-02, -1.7662e-01,  1.8629e-01, -6.0084e-02, -1.0374e-01,
#           7.6331e-02],
#         [ 5.5914e-02, -1.4660e-01, -3.0199e-02,  1.1367e-01, -2.2873e-01,
#           4.6192e-03,  2.3986e-01, -2.2636e-01, -1.1887e-04,  1.5854e-01,
#          -2.2687e-01,  1.1218e-01, -1.2671e-01, -1.0015e-01,  1.0271e-02,
#           1.3589e-01],
#         [-9.7129e-02,  1.6090e-01, -6.0578e-02, -2.4264e-01, -2.2957e-01,
#           5.4906e-02, -3.6554e-02,  9.9582e-03,  1.9435e-02,  2.4042e-01,
#           6.8563e-02,  8.0413e-02,  8.8018e-02, -7.4468e-02, -1.9721e-01,
#          -4.1780e-02],
#         [-1.6930e-02, -1.5074e-01,  1.3155e-01,  3.7266e-02,  1.3837e-01,
#          -1.2099e-01, -2.4410e-01,  1.3085e-01,  4.5128e-02, -2.1307e-01,
#           1.4022e-01, -1.3615e-01, -1.4611e-01,  2.1285e-01,  1.9073e-01,
#           1.3978e-01],
#         [ 2.1276e-01, -8.8183e-02, -2.1524e-01,  1.3555e-01,  2.3050e-01,
#           1.8695e-01, -5.3582e-04,  5.4169e-02, -2.2310e-01,  6.4159e-02,
#          -9.8398e-02,  2.4402e-01, -1.4702e-01, -2.1385e-01, -1.9836e-01,
#          -1.9128e-02],
#         [-6.5376e-02, -1.5073e-01,  2.4937e-01,  1.8552e-01, -2.4571e-01,
#          -7.8520e-02, -9.8082e-02, -6.9017e-02,  1.3458e-01,  1.6583e-01,
#           8.9642e-03,  2.2378e-01, -2.2639e-01, -9.9579e-02,  1.8914e-01,
#           1.1115e-02],
#         [-1.3414e-01, -9.6214e-02, -8.2752e-02, -2.4273e-01,  2.1977e-01,
#          -1.0215e-01, -3.3052e-02,  1.3298e-01, -1.3613e-01,  1.9924e-01,
#          -1.7772e-01,  5.7179e-02, -1.5272e-01,  9.6335e-02, -6.2323e-02,
#          -1.9112e-02],
#         [ 2.3021e-01,  2.1389e-01,  8.2684e-02,  5.3463e-02, -1.9245e-01,
#          -2.3607e-01, -1.5486e-01, -6.7137e-04,  1.5203e-01, -1.1185e-01,
#          -2.0160e-01, -7.8002e-02,  4.0819e-02,  1.1923e-01,  6.4357e-02,
#          -1.1633e-01],
#         [ 2.1180e-01,  2.1429e-01, -1.0688e-01,  2.2732e-01,  1.9507e-03,
#           4.5846e-02, -1.2734e-01, -2.4969e-01,  2.4155e-01, -1.8033e-01,
#          -1.2378e-01, -3.4434e-02,  2.0189e-01,  1.6845e-01, -2.0277e-03,
#          -1.9231e-01],
#         [ 1.0102e-01, -1.6758e-01, -4.5035e-02, -8.5399e-02, -1.5097e-01,
#          -4.1854e-04, -2.2778e-01, -3.0388e-02, -8.2494e-02, -8.1214e-02,
#          -5.4662e-02,  4.7084e-02,  2.2066e-01,  1.1836e-01,  9.4580e-02,
#           1.0436e-01],
#         [ 1.3025e-01, -1.1187e-01, -1.9736e-01,  1.3433e-01,  3.0434e-03,
#           1.2129e-01, -1.5909e-01,  7.2034e-02, -2.7467e-04,  2.4089e-01,
#           1.3175e-01, -1.2274e-01, -9.9845e-02, -1.4667e-01,  2.8676e-02,
#           1.7209e-01],
#         [ 5.2933e-02,  1.4900e-01,  2.4689e-01, -9.5358e-02,  2.1388e-01,
#           2.4026e-01, -1.2914e-01,  1.0328e-02, -7.0627e-02, -3.5425e-03,
#           1.3791e-01, -9.4922e-02, -3.1402e-02,  2.4817e-01, -1.9037e-01,
#          -7.3558e-02],
#         [ 1.2988e-02, -1.6174e-01, -1.7495e-01,  2.1797e-01,  1.1050e-02,
#          -2.5871e-02,  1.0910e-01,  8.5107e-02,  3.7206e-03, -1.0791e-01,
#          -3.5302e-02,  1.7089e-01, -1.8207e-01,  1.7123e-01,  2.4248e-01,
#           5.2487e-02],
#         [ 1.6229e-01,  1.6372e-01, -5.0416e-02, -2.0399e-01,  9.5053e-02,
#           3.7675e-03, -2.3978e-01,  1.3558e-01,  1.3072e-01, -1.7881e-01,
#           4.8913e-02, -1.2997e-02,  1.7579e-01,  2.0746e-01,  1.3701e-01,
#          -1.4607e-01]], dtype=torch.float64)
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -7.821570162438443 -159.01119995117188
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -7.821570162438443 -159.01119995117188
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -7.936916531423874 -158.8256072998047
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -7.895114033690781 -158.40586853027344
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -8.112596534826702 -156.85414123535156
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -8.01272202244126 -155.8744659423828
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -8.0336061353848 -155.48094177246094
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -8.257481088327548 -155.27052307128906
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -8.314354373436842 -154.5532684326172
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -8.1765226042145 -153.552001953125
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -7.7922539022713675 -152.8422393798828
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -7.053249084577329 -153.67372131347656
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -7.053249084577329 -153.67372131347656
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -7.057468267489071 -153.65574645996094
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -6.9154306307599445 -153.55712890625
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -7.04197165595827 -153.43890380859375
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -7.133542986799272 -153.35340881347656
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -7.948605561172068 -166.1290283203125
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -7.948605561172068 -166.1290283203125
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -7.816284167250711 -166.0715789794922
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -7.982751853752731 -165.90658569335938
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -7.877713291036361 -165.76052856445312
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -8.480879888250065 -154.6321563720703
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -8.480879888250065 -154.6321563720703
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -8.439111741221526 -154.57159423828125
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -8.18436175417141 -154.3240509033203
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -8.193030441654773 -153.9280548095703
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -8.568138741836659 -153.25244140625
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -8.831765138169704 -152.93728637695312
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -8.893840881370592 -152.59495544433594
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -8.859492249442363 -152.3590850830078
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -8.933987970770586 -151.91488647460938
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -8.938414886242626 -151.88668823242188
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -8.616016049588726 -151.71180725097656
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -8.408741131461278 -151.4991455078125
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -6.870153679241849 -170.59568786621094
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -6.870153679241849 -170.59568786621094
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -6.869791108617267 -170.5543212890625
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -7.012597637439205 -170.46505737304688
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -6.947361263655084 -170.34007263183594
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -7.083604103601308 -170.22357177734375
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -7.184092580681778 -169.94049072265625
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -7.240629183212761 -169.79782104492188
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -7.20051644819581 -169.60142517089844
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -7.00439301149725 -169.10145568847656
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -7.6378238877940205 -165.70321655273438
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -13.331886588740975 -277.656494140625
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -13.331886588740975 -277.656494140625
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -13.370462510543337 -277.56689453125
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -13.2275012155343 -277.3987121582031
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -13.1501979936683 -277.2259826660156
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -29.918420017357953 -562.7276000976562
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -29.918420017357953 -562.7276000976562
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -29.9306574078336 -562.6837768554688
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -30.376423386596187 -562.2646484375
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -30.479704569586787 -561.909423828125
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -30.40414595444653 -561.7413940429688
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -30.054316965100664 -560.6213989257812
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -30.487597278390105 -559.9010620117188
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -25.85705316146316 -562.7203369140625
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -25.85705316146316 -562.7203369140625
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -26.038667618531395 -562.6865844726562
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -25.85504827231566 -562.627197265625
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -25.551969270636356 -562.4094848632812
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -25.92039195164483 -562.1253662109375
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -25.148183507148588 -561.3733520507812
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -26.961775051632976 -559.5855102539062
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -24.966167300658547 -560.1976928710938
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -24.56999386556612 -559.02783203125
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -26.075154965717992 -557.8651733398438
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -25.20480621720497 -556.760009765625
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -24.38231760684583 -556.2178344726562
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -26.0340283115549 -551.9189453125
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -25.39634468049222 -551.0167846679688
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -25.358285967238743 -550.9707641601562
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -26.378845935705975 -544.1420288085938
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -8.014635924801894 -169.78396606445312
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -8.014635924801894 -169.78396606445312
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -7.995185759761178 -169.75390625
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -29.30146215867957 -549.4208374023438
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -29.30146215867957 -549.4208374023438
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -29.259658781950467 -549.3633422851562
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -29.41655719774551 -548.9020385742188
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -29.124302576407274 -547.4733276367188
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -29.26969654854522 -546.0861206054688
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -31.09786621551546 -544.0519409179688
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -31.09786621551546 -544.0519409179688
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -30.954769860310638 -543.9437866210938
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -29.949328559404005 -543.3881225585938
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -30.611145543867522 -542.2127685546875
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -29.975602502184614 -541.1334838867188
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -29.614376205654395 -540.047119140625
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -29.21617127534832 -538.7857055664062
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -29.682536423870083 -539.6726684570312
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -15.63303212179122 -279.4229736328125
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -27.44631429500475 -591.80908203125
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -27.44631429500475 -591.80908203125
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -27.422684515300066 -591.5975952148438
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -27.990988596250766 -591.2819213867188
# Epoch 1/10 Batch 2
# Predicted Energy and actual energy: -28.19026306601548 -589.4938354492188
# Loss: 141945.984375
# fc2.weight tensor([[-2.3017e-02,  2.4867e-01, -9.0384e-02,  2.2981e-01, -2.0484e-01,
#          -7.7866e-03,  1.2468e-01, -1.2984e-01,  3.2675e-02, -1.8956e-01,
#           1.7521e-01, -2.0414e-01, -1.8847e-01, -1.8600e-01, -1.6917e-01,
#          -1.3337e-01],
#         [-1.7104e-01, -2.1066e-01, -1.5134e-01, -9.9021e-02, -1.8519e-01,
#          -1.1152e-02, -6.8181e-02, -8.8197e-02, -1.1343e-01, -2.4065e-01,
#           1.3579e-01, -7.6533e-02,  2.0688e-01,  4.0513e-02, -9.6893e-02,
#          -2.3026e-02],
#         [ 7.6858e-02,  2.0925e-01, -1.9633e-01,  1.4729e-01,  3.5941e-02,
#           1.9597e-01,  3.7686e-02, -8.8825e-02,  3.4985e-02, -2.0993e-01,
#          -1.1715e-02, -1.7662e-01,  1.8629e-01, -6.0084e-02, -1.0374e-01,
#           7.6331e-02],
#         [ 5.5914e-02, -1.4660e-01, -3.0199e-02,  1.1367e-01, -2.2873e-01,
#           4.6192e-03,  2.3986e-01, -2.2636e-01, -1.1887e-04,  1.5854e-01,
#          -2.2687e-01,  1.1218e-01, -1.2671e-01, -1.0015e-01,  1.0271e-02,
#           1.3589e-01],
#         [-9.7129e-02,  1.6090e-01, -6.0578e-02, -2.4264e-01, -2.2957e-01,
#           5.4906e-02, -3.6554e-02,  9.9582e-03,  1.9435e-02,  2.4042e-01,
#           6.8563e-02,  8.0413e-02,  8.8018e-02, -7.4468e-02, -1.9721e-01,
#          -4.1780e-02],
#         [-1.6930e-02, -1.5074e-01,  1.3155e-01,  3.7266e-02,  1.3837e-01,
#          -1.2099e-01, -2.4410e-01,  1.3085e-01,  4.5128e-02, -2.1307e-01,
#           1.4022e-01, -1.3615e-01, -1.4611e-01,  2.1285e-01,  1.9073e-01,
#           1.3978e-01],
#         [ 2.1276e-01, -8.8183e-02, -2.1524e-01,  1.3555e-01,  2.3050e-01,
#           1.8695e-01, -5.3582e-04,  5.4169e-02, -2.2310e-01,  6.4159e-02,
#          -9.8398e-02,  2.4402e-01, -1.4702e-01, -2.1385e-01, -1.9836e-01,
#          -1.9128e-02],
#         [-6.5376e-02, -1.5073e-01,  2.4937e-01,  1.8552e-01, -2.4571e-01,
#          -7.8520e-02, -9.8082e-02, -6.9017e-02,  1.3458e-01,  1.6583e-01,
#           8.9642e-03,  2.2378e-01, -2.2639e-01, -9.9579e-02,  1.8914e-01,
#           1.1115e-02],
#         [-1.3414e-01, -9.6214e-02, -8.2752e-02, -2.4273e-01,  2.1977e-01,
#          -1.0215e-01, -3.3052e-02,  1.3298e-01, -1.3613e-01,  1.9924e-01,
#          -1.7772e-01,  5.7179e-02, -1.5272e-01,  9.6335e-02, -6.2323e-02,
#          -1.9112e-02],
#         [ 2.3021e-01,  2.1389e-01,  8.2684e-02,  5.3463e-02, -1.9245e-01,
#          -2.3607e-01, -1.5486e-01, -6.7137e-04,  1.5203e-01, -1.1185e-01,
#          -2.0160e-01, -7.8002e-02,  4.0819e-02,  1.1923e-01,  6.4357e-02,
#          -1.1633e-01],
#         [ 2.1180e-01,  2.1429e-01, -1.0688e-01,  2.2732e-01,  1.9507e-03,
#           4.5846e-02, -1.2734e-01, -2.4969e-01,  2.4155e-01, -1.8033e-01,
#          -1.2378e-01, -3.4434e-02,  2.0189e-01,  1.6845e-01, -2.0277e-03,
#          -1.9231e-01],
#         [ 1.0102e-01, -1.6758e-01, -4.5035e-02, -8.5399e-02, -1.5097e-01,
#          -4.1854e-04, -2.2778e-01, -3.0388e-02, -8.2494e-02, -8.1214e-02,
#          -5.4662e-02,  4.7084e-02,  2.2066e-01,  1.1836e-01,  9.4580e-02,
#           1.0436e-01],
#         [ 1.3025e-01, -1.1187e-01, -1.9736e-01,  1.3433e-01,  3.0434e-03,
#           1.2129e-01, -1.5909e-01,  7.2034e-02, -2.7467e-04,  2.4089e-01,
#           1.3175e-01, -1.2274e-01, -9.9845e-02, -1.4667e-01,  2.8676e-02,
#           1.7209e-01],
#         [ 5.2933e-02,  1.4900e-01,  2.4689e-01, -9.5358e-02,  2.1388e-01,
#           2.4026e-01, -1.2914e-01,  1.0328e-02, -7.0627e-02, -3.5425e-03,
#           1.3791e-01, -9.4922e-02, -3.1402e-02,  2.4817e-01, -1.9037e-01,
#          -7.3558e-02],
#         [ 1.2988e-02, -1.6174e-01, -1.7495e-01,  2.1797e-01,  1.1050e-02,
#          -2.5871e-02,  1.0910e-01,  8.5107e-02,  3.7206e-03, -1.0791e-01,
#          -3.5302e-02,  1.7089e-01, -1.8207e-01,  1.7123e-01,  2.4248e-01,
#           5.2487e-02],
#         [ 1.6229e-01,  1.6372e-01, -5.0416e-02, -2.0399e-01,  9.5053e-02,
#           3.7675e-03, -2.3978e-01,  1.3558e-01,  1.3072e-01, -1.7881e-01,
#           4.8913e-02, -1.2997e-02,  1.7579e-01,  2.0746e-01,  1.3701e-01,
#          -1.4607e-01]], dtype=torch.float64)
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -27.940142755362228 -589.30029296875
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -7.990352829323746 -169.84115600585938
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -7.990352829323746 -169.84115600585938
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -8.170109318068608 -169.78565979003906
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -15.960694447840893 -282.67266845703125
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -13.424784588422067 -299.0736389160156
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -13.424784588422067 -299.0736389160156
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -13.115347178335941 -298.84228515625
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -12.585607367430772 -297.9523010253906
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -12.761300902918094 -297.5878601074219
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -11.826891088849013 -297.14111328125
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -12.20475053411797 -296.9068298339844
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -29.153682065058703 -581.3762817382812
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -29.153682065058703 -581.3762817382812
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -29.18294427366686 -581.3546142578125
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -29.841182100589215 -582.6495361328125
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -29.841182100589215 -582.6495361328125
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -29.600871489208078 -582.5026245117188
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -28.64267884615176 -581.377197265625
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -28.39533608311367 -580.7382202148438
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -27.69543825976875 -580.3358764648438
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -26.843067435585073 -579.2503051757812
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -27.45005273133037 -575.6871948242188
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -26.576088634481117 -572.933349609375
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -13.702430135196597 -301.6312255859375
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -13.702430135196597 -301.6312255859375
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -13.984977239039777 -301.5546569824219
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -14.289219412483618 -301.2471008300781
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -14.086209360030866 -301.0960388183594
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -14.264649890710208 -300.68341064453125
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -14.426452398379844 -300.57598876953125
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -14.101677972184605 -299.6200256347656
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -8.470379960674192 -133.8771514892578
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -8.470379960674192 -133.8771514892578
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -8.458239919063686 -132.2742156982422
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -14.799249418248202 -298.2645568847656
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -14.799249418248202 -298.2645568847656
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -14.475576430734526 -298.1100158691406
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -14.380036429582786 -297.40093994140625
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -15.16069245623493 -296.021240234375
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -15.05247754813186 -295.1526794433594
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -15.094049157661294 -294.91778564453125
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -14.668057362726987 -294.82928466796875
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -14.545178614247728 -294.6865234375
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -16.12703470102193 -288.1708679199219
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -16.186078368248204 -288.091796875
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -7.23858565124086 -157.3342742919922
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -7.23858565124086 -157.3342742919922
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -7.238442628127739 -157.21934509277344
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -7.2968835666968435 -157.1230926513672
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -8.01024375199975 -169.36143493652344
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -8.01024375199975 -169.36143493652344
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -7.989297862038008 -169.35366821289062
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -7.752440935336329 -169.1297607421875
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -7.734184319086901 -169.1204376220703
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -8.003006715144291 -168.90382385253906
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -14.997771658970999 -302.4106750488281
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -14.997771658970999 -302.4106750488281
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -14.971074873993874 -302.34649658203125
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -15.006309626415 -302.1861267089844
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -14.106137609390684 -300.6712646484375
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -14.106137609390684 -300.6712646484375
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -13.971258170028907 -300.6106262207031
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -14.015134447816553 -300.3941650390625
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -13.96582274755209 -300.2218017578125
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -13.866103049237585 -299.99432373046875
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -13.838394472796868 -299.8301696777344
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -14.016349743453906 -299.4757080078125
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -12.789838544480117 -297.0111083984375
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -6.94032361756361 -160.8577117919922
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -6.94032361756361 -160.8577117919922
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -7.031295821879622 -160.69769287109375
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -7.053836269956366 -160.6181640625
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -20.7396443241229 -580.462646484375
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -20.7396443241229 -580.462646484375
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -20.4830462671465 -580.3314208984375
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -20.445327161234253 -578.954345703125
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -20.662198710205722 -578.2584228515625
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -19.396321996433603 -577.0501708984375
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -20.373134581919334 -575.4219360351562
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -20.69501063180983 -574.9439086914062
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -21.94809096088729 -571.819580078125
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -22.533465462120105 -570.1012573242188
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -24.457590129760007 -567.9672241210938
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -27.070540592167625 -562.911865234375
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -24.187711621409772 -561.6627197265625
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -22.144707495776146 -558.5772705078125
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -12.794834550292357 -262.946533203125
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -12.794834550292357 -262.946533203125
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -12.735601347175084 -262.90155029296875
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -12.783911345542936 -262.7510681152344
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -12.58253711392779 -262.6582946777344
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -12.684425461448768 -262.1175842285156
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -12.61387688800308 -261.6757507324219
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -12.387307349080563 -261.29815673828125
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -12.643216867446021 -260.06060791015625
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -29.30088806453014 -576.8453369140625
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -29.30088806453014 -576.8453369140625
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -29.018491452490583 -576.399169921875
# Epoch 1/10 Batch 3
# Predicted Energy and actual energy: -29.54360485837517 -575.3030395507812
# Loss: 136687.34375
# fc2.weight tensor([[-2.3017e-02,  2.4867e-01, -9.0384e-02,  2.2981e-01, -2.0484e-01,
#          -7.7866e-03,  1.2468e-01, -1.2984e-01,  3.2675e-02, -1.8956e-01,
#           1.7521e-01, -2.0414e-01, -1.8847e-01, -1.8600e-01, -1.6917e-01,
#          -1.3337e-01],
#         [-1.7104e-01, -2.1066e-01, -1.5134e-01, -9.9021e-02, -1.8519e-01,
#          -1.1152e-02, -6.8181e-02, -8.8197e-02, -1.1343e-01, -2.4065e-01,
#           1.3579e-01, -7.6533e-02,  2.0688e-01,  4.0513e-02, -9.6893e-02,
#          -2.3026e-02],
#         [ 7.6858e-02,  2.0925e-01, -1.9633e-01,  1.4729e-01,  3.5941e-02,
#           1.9597e-01,  3.7686e-02, -8.8825e-02,  3.4985e-02, -2.0993e-01,
#          -1.1715e-02, -1.7662e-01,  1.8629e-01, -6.0084e-02, -1.0374e-01,
#           7.6331e-02],
#         [ 5.5914e-02, -1.4660e-01, -3.0199e-02,  1.1367e-01, -2.2873e-01,
#           4.6192e-03,  2.3986e-01, -2.2636e-01, -1.1887e-04,  1.5854e-01,
#          -2.2687e-01,  1.1218e-01, -1.2671e-01, -1.0015e-01,  1.0271e-02,
#           1.3589e-01],
#         [-9.7129e-02,  1.6090e-01, -6.0578e-02, -2.4264e-01, -2.2957e-01,
#           5.4906e-02, -3.6554e-02,  9.9582e-03,  1.9435e-02,  2.4042e-01,
#           6.8563e-02,  8.0413e-02,  8.8018e-02, -7.4468e-02, -1.9721e-01,
#          -4.1780e-02],
#         [-1.6930e-02, -1.5074e-01,  1.3155e-01,  3.7266e-02,  1.3837e-01,
#          -1.2099e-01, -2.4410e-01,  1.3085e-01,  4.5128e-02, -2.1307e-01,
#           1.4022e-01, -1.3615e-01, -1.4611e-01,  2.1285e-01,  1.9073e-01,
#           1.3978e-01],
#         [ 2.1276e-01, -8.8183e-02, -2.1524e-01,  1.3555e-01,  2.3050e-01,
#           1.8695e-01, -5.3582e-04,  5.4169e-02, -2.2310e-01,  6.4159e-02,
#          -9.8398e-02,  2.4402e-01, -1.4702e-01, -2.1385e-01, -1.9836e-01,
#          -1.9128e-02],
#         [-6.5376e-02, -1.5073e-01,  2.4937e-01,  1.8552e-01, -2.4571e-01,
#          -7.8520e-02, -9.8082e-02, -6.9017e-02,  1.3458e-01,  1.6583e-01,
#           8.9642e-03,  2.2378e-01, -2.2639e-01, -9.9579e-02,  1.8914e-01,
#           1.1115e-02],
#         [-1.3414e-01, -9.6214e-02, -8.2752e-02, -2.4273e-01,  2.1977e-01,
#          -1.0215e-01, -3.3052e-02,  1.3298e-01, -1.3613e-01,  1.9924e-01,
#          -1.7772e-01,  5.7179e-02, -1.5272e-01,  9.6335e-02, -6.2323e-02,
#          -1.9112e-02],
#         [ 2.3021e-01,  2.1389e-01,  8.2684e-02,  5.3463e-02, -1.9245e-01,
#          -2.3607e-01, -1.5486e-01, -6.7137e-04,  1.5203e-01, -1.1185e-01,
#          -2.0160e-01, -7.8002e-02,  4.0819e-02,  1.1923e-01,  6.4357e-02,
#          -1.1633e-01],
#         [ 2.1180e-01,  2.1429e-01, -1.0688e-01,  2.2732e-01,  1.9507e-03,
#           4.5846e-02, -1.2734e-01, -2.4969e-01,  2.4155e-01, -1.8033e-01,
#          -1.2378e-01, -3.4434e-02,  2.0189e-01,  1.6845e-01, -2.0277e-03,
#          -1.9231e-01],
#         [ 1.0102e-01, -1.6758e-01, -4.5035e-02, -8.5399e-02, -1.5097e-01,
#          -4.1854e-04, -2.2778e-01, -3.0388e-02, -8.2494e-02, -8.1214e-02,
#          -5.4662e-02,  4.7084e-02,  2.2066e-01,  1.1836e-01,  9.4580e-02,
#           1.0436e-01],
#         [ 1.3025e-01, -1.1187e-01, -1.9736e-01,  1.3433e-01,  3.0434e-03,
#           1.2129e-01, -1.5909e-01,  7.2034e-02, -2.7467e-04,  2.4089e-01,
#           1.3175e-01, -1.2274e-01, -9.9845e-02, -1.4667e-01,  2.8676e-02,
#           1.7209e-01],
#         [ 5.2933e-02,  1.4900e-01,  2.4689e-01, -9.5358e-02,  2.1388e-01,
#           2.4026e-01, -1.2914e-01,  1.0328e-02, -7.0627e-02, -3.5425e-03,
#           1.3791e-01, -9.4922e-02, -3.1402e-02,  2.4817e-01, -1.9037e-01,
#          -7.3558e-02],
#         [ 1.2988e-02, -1.6174e-01, -1.7495e-01,  2.1797e-01,  1.1050e-02,
#          -2.5871e-02,  1.0910e-01,  8.5107e-02,  3.7206e-03, -1.0791e-01,
#          -3.5302e-02,  1.7089e-01, -1.8207e-01,  1.7123e-01,  2.4248e-01,
#           5.2487e-02],
#         [ 1.6229e-01,  1.6372e-01, -5.0416e-02, -2.0399e-01,  9.5053e-02,
#           3.7675e-03, -2.3978e-01,  1.3558e-01,  1.3072e-01, -1.7881e-01,
#           4.8913e-02, -1.2997e-02,  1.7579e-01,  2.0746e-01,  1.3701e-01,
#          -1.4607e-01]], dtype=torch.float64)
# Epoch 1/10 Batch 4
# Predicted Energy and actual energy: -30.10794787572863 -573.9505004882812
# Epoch 1/10 Batch 4
# Predicted Energy and actual energy: -30.412661883606994 -573.080078125
# Epoch 1/10 Batch 4
# Predicted Energy and actual energy: -30.34373267864481 -571.5159301757812
# Epoch 1/10 Batch 4
# Predicted Energy and actual energy: -30.065239690364894 -570.1339721679688
# Epoch 1/10 Batch 4
# Predicted Energy and actual energy: -29.91501439685802 -568.2103881835938
# Epoch 1/10 Batch 4
# Predicted Energy and actual energy: -28.881986357096086 -567.4651489257812
# Epoch 1/10 Batch 4
# Predicted Energy and actual energy: -13.610920464606414 -286.39447021484375
# Epoch 1/10 Batch 4
# Predicted Energy and actual energy: -13.610920464606414 -286.39447021484375
# Epoch 1/10 Batch 4
# Predicted Energy and actual energy: -13.244110675053266 -286.2837829589844
# Epoch 1/10 Batch 4
# Predicted Energy and actual energy: -12.643159146546967 -286.04168701171875
# Epoch 1/10 Batch 4
# Predicted Energy and actual energy: -12.596268576933795 -285.5682373046875
# Epoch 1/10 Batch 4
# Predicted Energy and actual energy: -12.82121138198596 -285.2240295410156
# Epoch 1/10 Batch 4
# Predicted Energy and actual energy: -24.49048394739168 -568.8297729492188
# Epoch 1/10 Batch 4
# Predicted Energy and actual energy: -24.49048394739168 -568.8297729492188
# Epoch 1/10 Batch 4
# Predicted Energy and actual energy: -24.37499348680128 -568.6992797851562
# Epoch 1/10 Batch 4
# Predicted Energy and actual energy: -24.748793112739474 -568.4556884765625
# Epoch 1/10 Batch 4
# Predicted Energy and actual energy: -25.064306065863818 -567.0728149414062
# Epoch 1/10 Batch 4
# Predicted Energy and actual energy: -25.477080110694896 -566.3998413085938
# Epoch 1/10 Batch 4
# Predicted Energy and actual energy: -25.180262683893368 -561.1592407226562
# Epoch 1/10 Batch 4
# Predicted Energy and actual energy: -24.90782815581169 -560.5684204101562
# Epoch 1/10 Batch 4
# Predicted Energy and actual energy: -24.93628522015573 -559.9193115234375
# Epoch 1/10 Batch 4
# Predicted Energy and actual energy: -7.9150439302232325 -156.4084014892578
# Epoch 1/10 Batch 4
# Predicted Energy and actual energy: -7.9150439302232325 -156.4084014892578
# Epoch 1/10 Batch 4
# Predicted Energy and actual energy: -7.547095166379442 -156.34458923339844
# Epoch 1/10 Batch 4
# Predicted Energy and actual energy: -29.08582614524249 -554.4696655273438
# Epoch 1/10 Batch 4
# Predicted Energy and actual energy: -29.08582614524249 -554.4696655273438
# Epoch 1/10 Batch 4
# Predicted Energy and actual energy: -29.07942048872659 -554.4227905273438
# Epoch 1/10 Batch 4
# Predicted Energy and actual energy: -28.700535786582456 -554.138427734375
# Epoch 1/10 Batch 4
# Predicted Energy and actual energy: -27.72481230242023 -586.5980834960938
# Epoch 1/10 Batch 4
# Predicted Energy and actual energy: -27.72481230242023 -586.5980834960938
# Epoch 1/10 Batch 4
# Predicted Energy and actual energy: -27.916587733596668 -586.4629516601562
# Epoch 1/10 Batch 4
# Predicted Energy and actual energy: -28.566728642354462 -585.4697875976562
# Epoch 1/10 Batch 4
# Predicted Energy and actual energy: -28.52070313715508 -585.001708984375
# Epoch 1/10 Batch 4
# Predicted Energy and actual energy: -28.69928326611581 -582.9401245117188
# Epoch 1/10 Batch 4
# Predicted Energy and actual energy: -28.76714929172498 -580.1246337890625
# Epoch 1/10 Batch 4
# Predicted Energy and actual energy: -28.27596909863709 -579.0318603515625
# Epoch 1/10 Batch 4
# Predicted Energy and actual energy: -27.34366430477162 -577.5697021484375
# Epoch 1/10 Batch 4
# Predicted Energy and actual energy: -29.523023468980867 -574.9129028320312
# Epoch 1/10 Batch 4
# Predicted Energy and actual energy: -29.36637563472317 -573.8187255859375
# Epoch 1/10 Batch 4
# Predicted Energy and actual energy: -27.224778947158118 -572.7907104492188
# Epoch 1/10 Batch 4
# Predicted Energy and actual energy: -27.59444360769644 -568.578369140625
# Epoch 1/10 Batch 4
# Predicted Energy and actual energy: -26.62455811225407 -565.7871704101562
# Epoch 1/10 Batch 4
# Predicted Energy and actual energy: -26.304364947431065 -565.10791015625
# Epoch 1/10 Batch 4
# Predicted Energy and actual energy: -8.702171380479294 -157.5826873779297
# Epoch 1/10 Batch 4
# Predicted Energy and actual energy: -8.702171380479294 -157.5826873779297
# Epoch 1/10 Batch 4
# Predicted Energy and actual energy: -8.60227133692886 -157.55072021484375
# Epoch 1/10 Batch 4
# Predicted Energy and actual energy: -8.455332843012101 -157.431640625
# Epoch 1/10 Batch 4
# Predicted Energy and actual energy: -8.389937738459183 -157.06472778320312
# Epoch 1/10 Batch 4
# Predicted Energy and actual energy: -8.361721338123028 -157.056396484375
# Epoch 1/10 Batch 4
# Predicted Energy and actual energy: -8.502299919105921 -156.69139099121094
# Epoch 1/10 Batch 4
# Predicted Energy and actual energy: -8.066945700314532 -156.44483947753906
# Epoch 1/10 Batch 4
# Predicted Energy and actual energy: -26.699702614857568 -554.747802734375
# Epoch 1/10 Batch 4
# Predicted Energy and actual energy: -26.699702614857568 -554.747802734375
# Epoch 1/10 Batch 4
# Predicted Energy and actual energy: -26.36145044005238 -554.6192016601562
# Epoch 1/10 Batch 4
# Predicted Energy and actual energy: -26.420832999828903 -554.3215942382812
# Epoch 1/10 Batch 4
# Predicted Energy and actual energy: -26.201901233127188 -553.8466186523438
# Epoch 1/10 Batch 4
# Predicted Energy and actual energy: -24.985454190709923 -552.5676879882812
# Epoch 1/10 Batch 4
# Predicted Energy and actual energy: -25.3579528062054 -552.2689208984375
# Epoch 1/10 Batch 4
# Predicted Energy and actual energy: -26.4959687848227 -550.6095581054688
# Epoch 1/10 Batch 4
# Predicted Energy and actual energy: -25.554112596012764 -582.952392578125
# Epoch 1/10 Batch 4
# Predicted Energy and actual energy: -25.554112596012764 -582.952392578125
# Epoch 1/10 Batch 4
# Predicted Energy and actual energy: -25.927819612946184 -582.8648681640625
# Epoch 1/10 Batch 4
# Predicted Energy and actual energy: -26.291051872649824 -582.260009765625
# Epoch 1/10 Batch 4
# Predicted Energy and actual energy: -26.358150731298217 -581.6554565429688
# Epoch 1/10 Batch 4
# Predicted Energy and actual energy: -25.053753968395768 -579.7105102539062
# Epoch 1/10 Batch 4
# Predicted Energy and actual energy: -26.07758936623695 -578.4646606445312
# Epoch 1/10 Batch 4
# Predicted Energy and actual energy: -28.40300100879195 -576.4163818359375
# Epoch 1/10 Batch 4
# Predicted Energy and actual energy: -28.801525553266657 -575.6619262695312
# Epoch 1/10 Batch 4
# Predicted Energy and actual energy: -5.676256376567062 -153.42813110351562
# Epoch 1/10 Batch 4
# Predicted Energy and actual energy: -5.676256376567062 -153.42813110351562
# Epoch 1/10 Batch 4
# Predicted Energy and actual energy: -5.5247233507848375 -153.3888702392578
# Epoch 1/10 Batch 4
# Predicted Energy and actual energy: -5.430422079116243 -153.31161499023438
# Epoch 1/10 Batch 4
# Predicted Energy and actual energy: -5.478387226608389 -153.30067443847656
# Epoch 1/10 Batch 4
# Predicted Energy and actual energy: -5.607483202189089 -153.04373168945312
# Epoch 1/10 Batch 4
# Predicted Energy and actual energy: -5.625382289954514 -152.88706970214844
# Epoch 1/10 Batch 4
# Predicted Energy and actual energy: -5.741778489891641 -152.8657989501953
# Epoch 1/10 Batch 4
# Predicted Energy and actual energy: -6.213586367947293 -152.4287109375
# Epoch 1/10 Batch 4
# Predicted Energy and actual energy: -6.486260041237715 -151.78016662597656
# Epoch 1/10 Batch 4
# Predicted Energy and actual energy: -6.459180644315234 -151.52151489257812
# Epoch 1/10 Batch 4
# Predicted Energy and actual energy: -6.4845208560122884 -151.15736389160156
# Epoch 1/10 Batch 4
# Predicted Energy and actual energy: -6.797379819662956 -150.62869262695312
# Epoch 1/10 Batch 4
# Predicted Energy and actual energy: -6.804400114213214 -150.5312957763672
# Epoch 1/10 Batch 4
# Predicted Energy and actual energy: -9.447362006683235 -142.07269287109375
# Epoch 1/10 Batch 4
# Predicted Energy and actual energy: -9.447362006683235 -142.07269287109375
# Epoch 1/10 Batch 4
# Predicted Energy and actual energy: -9.525700136576914 -141.9972381591797
# Epoch 1/10 Batch 4
# Predicted Energy and actual energy: -9.475926861256612 -140.21710205078125
# Epoch 1/10 Batch 4
# ...
#         [ 2.1276e-01, -8.8183e-02, -2.1524e-01,  1.3555e-01,  2.3050e-01,
#           1.8695e-01, -5.3582e-04,  5.4169e-02, -2.2310e-01,  6.4159e-02,
#          -9.8398e-02,  2.4402e-01, -1.4702e-01, -2.1385e-01, -1.9836e-01,
#          -1.9128e-02],
#         [-6.5376e-02, -1.5073e-01,  2.4937e-01,  1.8552e-01, -2.4571e-01,
#          -7.8520e-02, -9.8082e-02, -6.9017e-02,  1.3458e-01,  1.6583e-01,
#           8.9642e-03,  2.2378e-01, -2.2639e-01, -9.9579e-02,  1.8914e-01,
#           1.1115e-02],
#         [-1.3414e-01, -9.6214e-02, -8.2752e-02, -2.4273e-01,  2.1977e-01,
#          -1.0215e-01, -3.3052e-02,  1.3298e-01, -1.3613e-01,  1.9924e-01,
#          -1.7772e-01,  5.7179e-02, -1.5272e-01,  9.6335e-02, -6.2323e-02,
#          -1.9112e-02],
#         [ 2.3021e-01,  2.1389e-01,  8.2684e-02,  5.3463e-02, -1.9245e-01,
#          -2.3607e-01, -1.5486e-01, -6.7137e-04,  1.5203e-01, -1.1185e-01,
#          -2.0160e-01, -7.8002e-02,  4.0819e-02,  1.1923e-01,  6.4357e-02,
#          -1.1633e-01],
#         [ 2.1180e-01,  2.1429e-01, -1.0688e-01,  2.2732e-01,  1.9507e-03,
#           4.5846e-02, -1.2734e-01, -2.4969e-01,  2.4155e-01, -1.8033e-01,
#          -1.2378e-01, -3.4434e-02,  2.0189e-01,  1.6845e-01, -2.0277e-03,
#          -1.9231e-01],
#         [ 1.0102e-01, -1.6758e-01, -4.5035e-02, -8.5399e-02, -1.5097e-01,
#          -4.1854e-04, -2.2778e-01, -3.0388e-02, -8.2494e-02, -8.1214e-02,
#          -5.4662e-02,  4.7084e-02,  2.2066e-01,  1.1836e-01,  9.4580e-02,
#           1.0436e-01],
#         [ 1.3025e-01, -1.1187e-01, -1.9736e-01,  1.3433e-01,  3.0434e-03,
#           1.2129e-01, -1.5909e-01,  7.2034e-02, -2.7467e-04,  2.4089e-01,
#           1.3175e-01, -1.2274e-01, -9.9845e-02, -1.4667e-01,  2.8676e-02,
#           1.7209e-01],
#         [ 5.2933e-02,  1.4900e-01,  2.4689e-01, -9.5358e-02,  2.1388e-01,
#           2.4026e-01, -1.2914e-01,  1.0328e-02, -7.0627e-02, -3.5425e-03,
#           1.3791e-01, -9.4922e-02, -3.1402e-02,  2.4817e-01, -1.9037e-01,
#          -7.3558e-02],
#         [ 1.2988e-02, -1.6174e-01, -1.7495e-01,  2.1797e-01,  1.1050e-02,
#          -2.5871e-02,  1.0910e-01,  8.5107e-02,  3.7206e-03, -1.0791e-01,
#          -3.5302e-02,  1.7089e-01, -1.8207e-01,  1.7123e-01,  2.4248e-01,
#           5.2487e-02],
#         [ 1.6229e-01,  1.6372e-01, -5.0416e-02, -2.0399e-01,  9.5053e-02,
#           3.7675e-03, -2.3978e-01,  1.3558e-01,  1.3072e-01, -1.7881e-01,
#           4.8913e-02, -1.2997e-02,  1.7579e-01,  2.0746e-01,  1.3701e-01,
#          -1.4607e-01]], dtype=torch.float64)
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -25.662480308283627 -576.0153198242188
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -26.08490183238984 -575.8677368164062
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -25.256485715576797 -575.2726440429688
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -24.548774777444123 -574.809326171875
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -28.86050004767091 -580.7852172851562
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -27.9682209623552 -569.9082641601562
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -27.9682209623552 -569.9082641601562
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -27.867962804334894 -569.831787109375
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -28.006425404007327 -569.7049560546875
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -27.86655071798512 -568.8887329101562
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -28.447541962542548 -567.8341674804688
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -28.53806619567797 -567.5764770507812
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -29.363673590215114 -565.0980834960938
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -29.16993563333068 -577.055419921875
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -29.16993563333068 -577.055419921875
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -29.191331034899527 -576.9468383789062
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -28.528502365975076 -576.1325073242188
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -28.78003481678775 -575.52392578125
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -28.972510486843067 -574.5203247070312
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -28.15907094648314 -571.5308837890625
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -7.212428215692722 -156.0179443359375
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -7.212428215692722 -156.0179443359375
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -7.136241477172478 -155.94406127929688
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -7.493836152760187 -155.3369903564453
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -7.574519651485101 -155.33558654785156
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -25.72192261890538 -558.0485229492188
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -25.72192261890538 -558.0485229492188
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -25.79365713379523 -557.9791259765625
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -25.86985304069641 -557.6602172851562
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -26.411084534739413 -556.6710815429688
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -26.422232790658782 -556.2276611328125
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -26.496187026218497 -554.6765747070312
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -27.988109069117492 -569.3627319335938
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -27.988109069117492 -569.3627319335938
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -28.222415821378767 -568.8883056640625
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -28.13495582546239 -566.4605712890625
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -27.65801885041969 -565.3916015625
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -5.951562750399823 -164.0777587890625
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -5.951562750399823 -164.0777587890625
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -5.9515627503999795 -163.83673095703125
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -7.53885003579512 -163.69078063964844
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -6.231496310156828 -152.8378143310547
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -6.231496310156828 -152.8378143310547
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -6.17434056657512 -152.7593994140625
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -7.446963374454779 -157.0067901611328
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -7.446963374454779 -157.0067901611328
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -7.575386070445589 -156.71144104003906
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -8.046857427677384 -158.82815551757812
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -8.046857427677384 -158.82815551757812
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -8.049237813394138 -158.75213623046875
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -8.051895880830426 -158.504638671875
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -8.07589311442188 -158.4564208984375
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -8.100987845828854 -158.2058563232422
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -8.170021772273024 -157.8278350830078
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -7.783723045843738 -157.0390167236328
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -7.752563314834236 -156.64215087890625
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -7.766167077848721 -156.5321502685547
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -8.16627739958489 -154.92491149902344
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -11.694695125084479 -280.5168762207031
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -11.69492826939479 -280.5119934082031
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -11.71244116638495 -280.4996337890625
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -11.835271853226196 -280.46026611328125
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -12.489497355482225 -279.9414367675781
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -13.990773557876519 -308.2770080566406
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -13.990773557876519 -308.2770080566406
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -13.647363982856156 -308.1116943359375
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -13.755892474784343 -307.88726806640625
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -13.86806315012524 -306.79766845703125
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -8.71583146717233 -158.46139526367188
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -8.71583146717233 -158.46139526367188
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -8.731576247258115 -158.34872436523438
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -8.5937241553554 -158.11781311035156
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -12.785300930078156 -289.39129638671875
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -12.785300930078156 -289.39129638671875
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -12.815332541763084 -289.3514099121094
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -12.888203503203584 -289.1063537597656
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -12.724938750638515 -288.7828674316406
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -31.756854599255387 -564.5316772460938
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -31.756854599255387 -564.5316772460938
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -31.763087666483727 -564.4412231445312
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -31.50513469091853 -564.2417602539062
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -31.83907856005954 -564.0048217773438
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -32.44076970979562 -562.4115600585938
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -32.808314887024764 -561.630615234375
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -32.10523191210855 -561.6888427734375
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -31.727342546540918 -559.6583862304688
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -12.018329925787858 -285.7144470214844
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -12.018329925787858 -285.7144470214844
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -11.96042645740479 -285.633056640625
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -12.012962104780433 -285.4326477050781
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -11.973899069077424 -285.3990478515625
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -12.205006240320422 -285.22772216796875
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -12.351754303361052 -285.0678405761719
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -12.179495807898787 -285.08428955078125
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -8.293321725910205 -166.70074462890625
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -8.293321725910205 -166.70074462890625
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -8.255319432653101 -166.67791748046875
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -7.434354308131049 -166.57034301757812
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -6.584165625424366 -166.22674560546875
# Epoch 10/10 Batch 10
# Predicted Energy and actual energy: -6.648177622389596 -166.03573608398438
# Loss: 145129.03125
# fc2.weight tensor([[-2.3017e-02,  2.4867e-01, -9.0384e-02,  2.2981e-01, -2.0484e-01,
#          -7.7866e-03,  1.2468e-01, -1.2984e-01,  3.2675e-02, -1.8956e-01,
#           1.7521e-01, -2.0414e-01, -1.8847e-01, -1.8600e-01, -1.6917e-01,
#          -1.3337e-01],
#         [-1.7104e-01, -2.1066e-01, -1.5134e-01, -9.9021e-02, -1.8519e-01,
#          -1.1152e-02, -6.8181e-02, -8.8197e-02, -1.1343e-01, -2.4065e-01,
#           1.3579e-01, -7.6533e-02,  2.0688e-01,  4.0513e-02, -9.6893e-02,
#          -2.3026e-02],
#         [ 7.6858e-02,  2.0925e-01, -1.9633e-01,  1.4729e-01,  3.5941e-02,
#           1.9597e-01,  3.7686e-02, -8.8825e-02,  3.4985e-02, -2.0993e-01,
#          -1.1715e-02, -1.7662e-01,  1.8629e-01, -6.0084e-02, -1.0374e-01,
#           7.6331e-02],
#         [ 5.5914e-02, -1.4660e-01, -3.0199e-02,  1.1367e-01, -2.2873e-01,
#           4.6192e-03,  2.3986e-01, -2.2636e-01, -1.1887e-04,  1.5854e-01,
#          -2.2687e-01,  1.1218e-01, -1.2671e-01, -1.0015e-01,  1.0271e-02,
#           1.3589e-01],
#         [-9.7129e-02,  1.6090e-01, -6.0578e-02, -2.4264e-01, -2.2957e-01,
#           5.4906e-02, -3.6554e-02,  9.9582e-03,  1.9435e-02,  2.4042e-01,
#           6.8563e-02,  8.0413e-02,  8.8018e-02, -7.4468e-02, -1.9721e-01,
#          -4.1780e-02],
#         [-1.6930e-02, -1.5074e-01,  1.3155e-01,  3.7266e-02,  1.3837e-01,
#          -1.2099e-01, -2.4410e-01,  1.3085e-01,  4.5128e-02, -2.1307e-01,
#           1.4022e-01, -1.3615e-01, -1.4611e-01,  2.1285e-01,  1.9073e-01,
#           1.3978e-01],
#         [ 2.1276e-01, -8.8183e-02, -2.1524e-01,  1.3555e-01,  2.3050e-01,
#           1.8695e-01, -5.3582e-04,  5.4169e-02, -2.2310e-01,  6.4159e-02,
#          -9.8398e-02,  2.4402e-01, -1.4702e-01, -2.1385e-01, -1.9836e-01,
#          -1.9128e-02],
#         [-6.5376e-02, -1.5073e-01,  2.4937e-01,  1.8552e-01, -2.4571e-01,
#          -7.8520e-02, -9.8082e-02, -6.9017e-02,  1.3458e-01,  1.6583e-01,
#           8.9642e-03,  2.2378e-01, -2.2639e-01, -9.9579e-02,  1.8914e-01,
#           1.1115e-02],
#         [-1.3414e-01, -9.6214e-02, -8.2752e-02, -2.4273e-01,  2.1977e-01,
#          -1.0215e-01, -3.3052e-02,  1.3298e-01, -1.3613e-01,  1.9924e-01,
#          -1.7772e-01,  5.7179e-02, -1.5272e-01,  9.6335e-02, -6.2323e-02,
#          -1.9112e-02],
#         [ 2.3021e-01,  2.1389e-01,  8.2684e-02,  5.3463e-02, -1.9245e-01,
#          -2.3607e-01, -1.5486e-01, -6.7137e-04,  1.5203e-01, -1.1185e-01,
#          -2.0160e-01, -7.8002e-02,  4.0819e-02,  1.1923e-01,  6.4357e-02,
#          -1.1633e-01],
#         [ 2.1180e-01,  2.1429e-01, -1.0688e-01,  2.2732e-01,  1.9507e-03,
#           4.5846e-02, -1.2734e-01, -2.4969e-01,  2.4155e-01, -1.8033e-01,
#          -1.2378e-01, -3.4434e-02,  2.0189e-01,  1.6845e-01, -2.0277e-03,
#          -1.9231e-01],
#         [ 1.0102e-01, -1.6758e-01, -4.5035e-02, -8.5399e-02, -1.5097e-01,
#          -4.1854e-04, -2.2778e-01, -3.0388e-02, -8.2494e-02, -8.1214e-02,
#          -5.4662e-02,  4.7084e-02,  2.2066e-01,  1.1836e-01,  9.4580e-02,
#           1.0436e-01],
#         [ 1.3025e-01, -1.1187e-01, -1.9736e-01,  1.3433e-01,  3.0434e-03,
#           1.2129e-01, -1.5909e-01,  7.2034e-02, -2.7467e-04,  2.4089e-01,
#           1.3175e-01, -1.2274e-01, -9.9845e-02, -1.4667e-01,  2.8676e-02,
#           1.7209e-01],
#         [ 5.2933e-02,  1.4900e-01,  2.4689e-01, -9.5358e-02,  2.1388e-01,
#           2.4026e-01, -1.2914e-01,  1.0328e-02, -7.0627e-02, -3.5425e-03,
#           1.3791e-01, -9.4922e-02, -3.1402e-02,  2.4817e-01, -1.9037e-01,
#          -7.3558e-02],
#         [ 1.2988e-02, -1.6174e-01, -1.7495e-01,  2.1797e-01,  1.1050e-02,
#          -2.5871e-02,  1.0910e-01,  8.5107e-02,  3.7206e-03, -1.0791e-01,
#          -3.5302e-02,  1.7089e-01, -1.8207e-01,  1.7123e-01,  2.4248e-01,
#           5.2487e-02],
#         [ 1.6229e-01,  1.6372e-01, -5.0416e-02, -2.0399e-01,  9.5053e-02,
#           3.7675e-03, -2.3978e-01,  1.3558e-01,  1.3072e-01, -1.7881e-01,
#           4.8913e-02, -1.2997e-02,  1.7579e-01,  2.0746e-01,  1.3701e-01,
#          -1.4607e-01]], dtype=torch.float64)
